# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

dataset = pd.read_csv("./dataset/a_affirmative_datapoints.csv", sep=' ')
targets = pd.read_csv("./dataset/a_affirmative_targets.csv")
dataset = pd.concat([dataset, targets], axis=1)
dataset.drop([dataset.columns[0]], axis=1, inplace=True)

# %%
print(dataset.shape)
print(dataset.dtypes)
print(dataset.describe())
print(dataset.head())
print(dataset.groupby('target').size())

# %% [markdown]
# Como pode ser observado pelo describe, a maioria dos pontos possui um desvio padrão relativamente baixo.
