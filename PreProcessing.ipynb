# %%
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from support import getDFPointsAngles
from sklearn.preprocessing import MinMaxScaler

dataset = pd.read_csv("./dataset/a_affirmative_datapoints.csv", sep=' ')
targets = pd.read_csv("./dataset/a_affirmative_targets.csv")
dataset = pd.concat([dataset, targets], axis=1)
dataset.drop([dataset.columns[0]], axis=1, inplace=True)

# %%
dataset2 = getDFPointsAngles(dataset, targets)

# %%
dataset2.plot(kind='box', subplots=True, layout=(4,5), sharex=False, sharey=False)
plt.show()

# %%
dataset2.hist()
plt.show()

# %%
dataset2.describe()
# Out:
#                 d1           d2           d3           d4           d5  \
# count  1062.000000  1062.000000  1062.000000  1062.000000  1062.000000
# mean      9.461951     9.683706    20.565022    21.632685    23.898142
# std       0.739815     0.728803     1.575816     1.359748     1.208907
# min       7.194539     7.415665    17.390844    18.294864    20.863370
# 25%       8.998389     9.225419    19.320766    20.507058    23.082830
# 50%       9.392229     9.642824    20.420377    21.535965    23.918373
# 75%       9.874609    10.081315    21.582204    22.588060    24.676563
# max      15.688342    15.584138    30.423394    31.828928    29.933302
#
#                 d6           d7           d8           d9          d10  \
# count  1062.000000  1062.000000  1062.000000  1062.000000  1062.000000
# mean      8.998514     9.195321     8.086042    27.080019    20.406444
# std       0.338081     0.284920     0.654434     1.000110     1.130709
# min       8.305393     8.619184     6.452775    24.981436    17.094580
# 25%       8.789654     9.017848     7.623300    26.523986    19.561720
# 50%       9.009145     9.195927     8.035714    27.065881    20.570695
# 75%       9.172768     9.335130     8.533762    27.610301    21.208953
# max      12.767640    12.081116    12.860089    38.271126    27.866161
#
#                d11           a1           a2           a3           a4  \
# count  1062.000000  1062.000000  1062.000000  1062.000000  1062.000000
# mean     20.477323     1.411886     0.633197     0.656680     1.117872
# std       1.092052     0.080056     0.048127     0.051757     0.075241
# min      17.003963     1.224065     0.499372     0.503477     0.849461
# 25%      19.655988     1.356862     0.602152     0.623721     1.060067
# 50%      20.607284     1.409735     0.632643     0.656173     1.118965
# 75%      21.280048     1.458785     0.662248     0.688587     1.171751
# max      27.642458     1.701079     0.905593     0.944017     1.315451
#
#                 a5           a6           a7       target
# count  1062.000000  1062.000000  1062.000000  1062.000000
# mean      1.128510     0.345320     0.337955     0.389831
# std       0.074205     0.022471     0.021948     0.487941
# min       0.861594     0.256187     0.251474     0.000000
# 25%       1.072296     0.335191     0.327355     0.000000
# 50%       1.132573     0.348251     0.340489     0.000000
# 75%       1.181348     0.359427     0.350952     1.000000
# max       1.323593     0.404101     0.395755     1.000000

# %%
X = dataset2.iloc[:, :-1]
y = dataset2.iloc[:, -1]

XScaled = MinMaxScaler().fit_transform(X)
normDataset = pd.DataFrame(XScaled, columns = ['d1', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'd9',
         'd10', 'd11', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7']) 
normDataset['target'] = dataset['target']
normDataset.describe()
# Out:
#                 d1           d2           d3           d4           d5  \
# count  1062.000000  1062.000000  1062.000000  1062.000000  1062.000000
# mean      0.266949     0.277658     0.243558     0.246624     0.334597
# std       0.087101     0.089221     0.120914     0.100469     0.133287
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.212373     0.221554     0.148085     0.163454     0.244705
# 50%       0.258740     0.272653     0.232459     0.239477     0.336828
# 75%       0.315532     0.326334     0.321607     0.317214     0.420421
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 d6           d7           d8           d9          d10  \
# count  1062.000000  1062.000000  1062.000000  1062.000000  1062.000000
# mean      0.155330     0.166421     0.254907     0.157911     0.307463
# std       0.075765     0.082301     0.102139     0.075255     0.104972
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.108524     0.115157     0.182686     0.116071     0.229042
# 50%       0.157713     0.166596     0.247052     0.156847     0.322712
# 75%       0.194381     0.206805     0.324783     0.197812     0.381966
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                d11           a1           a2           a3           a4  \
# count  1062.000000  1062.000000  1062.000000  1062.000000  1062.000000
# mean      0.326490     0.393743     0.329439     0.347762     0.576001
# std       0.102651     0.167827     0.118475     0.117485     0.161465
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.249286     0.278392     0.253014     0.272947     0.451954
# 50%       0.338706     0.389233     0.328076     0.346611     0.578347
# 75%       0.401944     0.492060     0.400954     0.420188     0.691625
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 a5           a6           a7       target
# count  1062.000000  1062.000000  1062.000000  1062.000000
# mean      0.577740     0.602601     0.599394     0.389831
# std       0.160617     0.151917     0.152123     0.487941
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.456066     0.534120     0.525927     0.000000
# 50%       0.586536     0.622415     0.616957     0.000000
# 75%       0.692108     0.697974     0.689478     1.000000
# max       1.000000     1.000000     1.000000     1.000000
