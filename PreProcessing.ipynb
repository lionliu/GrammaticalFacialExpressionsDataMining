# %%
import numpy as np
import pandas as pd
from support import getDFPointsAngles

dataset = pd.read_csv("./dataset/a_affirmative_datapoints.csv", sep=' ')
targets = pd.read_csv("./dataset/a_affirmative_targets.csv")
dataset = pd.concat([dataset, targets], axis=1)
dataset.drop([dataset.columns[0]], axis=1, inplace=True)
dataset2 = getDFPointsAngles(dataset, targets)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7a8efe322cbe> in <module>
#       7 dataset = pd.concat([dataset, targets], axis=1)
#       8 dataset.drop([dataset.columns[0]], axis=1, inplace=True)
# ----> 9 dataset2 = getDFPointsAngles(dataset)
#
# TypeError: getDFPointsAngles() missing 1 required positional argument: 'targets'
