# %%
import numpy as np
import pandas as pd


dataset = pd.read_csv("./dataset/a_affirmative_datapoints.csv", sep=' ')
targets = pd.read_csv("./dataset/a_affirmative_targets.csv")
dataset = pd.concat([dataset, targets], axis=1)
dataset.drop([dataset.columns[0]], axis=1, inplace=True)

def pointDistance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2)**2 + (y1 - y2)**2)

def pointAngle(x1, y1, x2, y2):
    return np.arctan2(y2 - y1, x2 - x1)

# %%
dataset = dataset[['2x', '2y', '2z', '4x', '4y', '4z', '10x', '10y', '10z', 
'12x', '12y', '12z', '16x', '16y', '16z', '17x', '17y', '17z', '20x', '20y', '20z', 
'26x', '26y', '26z', '27x', '27y', '27z', '30x', '30y', '30z', '39x', '39y', '39z', 
'44x', '44y', '44z', '48x', '48y', '48z', '51x', '51y', '51z', '54x', '54y', '54z', 
'57x', '57y', '57z', '59x', '59y', '59z', 'target']]
